# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"As a helpful AI assistant you are tasked to generate the essay for the following topic : {topic}" 

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f'''As a helpful AI essay reviewer,  you are tasked to provide feedback on the essay draft.
    
    <guidelines>
    - Your feedback should be critical but constructive.
    - You feedback should address issues such as structure, clarity, strength of argument, and writing style.
    - You should return only the feedback on essay in your response.
    
    Here's the written essay draft:
    {draft}
    '''

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f'''As a helpful AI essay writer,  you are tasked to revise the essay basis the reviewer's feedback on the initial essay draft.
    
    <guidelines>
    - The revised draft should address the issues mentioned in the feedback.
    - You should improve clarity, coherence, argument strength, and overall flow.
    - You should use the feedback to improve the draft essay, and return only the final revised essay.
    
    Here's the written essay original draft:
    {original_draft}
    
    Here's the reviewer's Feedback on the original written essay draft:
    {reflection}
    
    
    '''
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )
    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: The Necessity of Government Regulation on Social Media Platforms
#
# Introduction
#
# In an increasingly interconnected world, social media platforms wield immense power in shaping public discourse, influencing opinions, and even impacting the outcomes of elections. As these platforms have grown, so has the debate around whether they should be regulated by the government. Proponents argue that regulation is necessary to curb misinformation, protect user privacy, and ensure fair practices, while opponents claim it might infringe on free speech and stifle innovation. This essay explores the necessity of government regulation on social media platforms, weighing the potential benefits against the possible drawbacks.
#
# The Case for Regulation
#
# 1. **Curbing Misinformation and Harmful Content**: Social media has become a fertile ground for the spread of misinformation, fake news, and harmful content. These platforms employ algorithms that often prioritize sensational content, which can lead to real-world consequences such as panic, violence, or erosion of trust in public institutions. Government regulation could establish clear guidelines and accountability measures for the dissemination of content, ensuring that platforms take responsibility for monitoring and managing harmful content.
#
# 2. **Protecting User Privacy**: The vast amount of personal data collected by social media companies poses significant privacy concerns. Users often lack control over their data and may not fully understand the extent to which it is used or monetized. Regulatory frameworks, such as the European General Data Protection Regulation (GDPR), can enforce standards for data protection, giving users more control over their personal information and holding companies accountable for breaches.
#
# 3. **Ensuring Fairness and Competition**: Social media giants hold significant market power, often engaging in anti-competitive practices that stifle start-ups and innovation. Government intervention could ensure a level playing field by preventing monopolistic behavior and fostering a competitive environment that encourages diversity and innovation.
#
# 4. **Safeguarding Democracy**: Social media platforms have played a controversial role in democratic processes worldwide, with concerns about election interference through targeted ads and misinformation campaigns. Regulatory measures could mandate transparency in political advertising and enforce stricter controls on these practices to protect the integrity of elections.
#
# The Case Against Regulation
#
# 1. **Risk of Censorship and Free Speech Concerns**: One of the primary arguments against government regulation is the potential for censorship. Regulatory bodies might misuse their power to suppress dissent or control narratives, thereby infringing on free speech. This concern underscores the need for a balanced approach that protects freedom of expression while addressing harmful content.
#
# 2. **Innovation and Economic Growth**: Social media platforms have been at the forefront of technological innovation, creating jobs and contributing significantly to economic growth. Overregulation might stifle innovation and deter investment in the industry. It is crucial to find a regulatory approach that does not hinder the technological advancement and entrepreneurial spirit that drive these platforms.
#
# 3. **Global and Legislative Complexity**: Social media platforms operate on a global scale, complicating regulatory efforts. Different countries have varying cultural norms and legal systems, making it challenging to implement universal regulations. Additionally, rapidly evolving technology means that regulations can quickly become outdated or insufficient.
#
# Conclusion
#
# The regulation of social media platforms by the government presents a complex challenge, requiring a careful balance between safeguarding public interests and preserving fundamental freedoms. While the risks associated with misinformation, privacy breaches, and unfair practices are too significant to ignore, it is crucial that any regulatory framework is transparent, adaptable, and respectful of free speech. A collaborative approach involving governments, industry leaders, and civil society can help build a regulatory environment that promotes responsibility, innovation, and the protection of democratic values. As social media continues to evolve, so too must the strategies to ensure its positive role in society.
#
# 🧠 Feedback:
#
# Structure
# - The overall organization into “Case for” and “Case against” sections is clear and logical, but the essay reads more like an outline than a flowing argument. Consider weaving these points into full paragraphs with smoother transitions so the reader follows the narrative, rather than jumping between numbered lists.
# - Your introduction sets up the debate well, but it could be strengthened by a more precise thesis statement that previews which side you find more compelling (or under what conditions regulation is justified).
# - The conclusion restates the need for balance, but it would benefit from a stronger call to action or a summary of your key recommendations (for example, specific regulatory principles or next steps).
#
# Clarity
# - The language is generally clear, but several sections rely heavily on broad generalizations (e.g., “real-world consequences,” “significant privacy concerns”). Citing concrete examples—such as the Cambridge Analytica scandal, 2016 election interference, or a landmark GDPR enforcement action—will ground your claims.
# - Watch for repetition of terms like “platforms,” “regulation,” and “harmful content.” Vary your wording or combine similar ideas to avoid redundancy and tighten your prose.
# - Some sentences are lengthy and pack multiple ideas. Breaking these into shorter, focused sentences will improve readability.
#
# Strength of Argument
# - Your essay identifies the central issues—misinformation, privacy, competition, democracy, free speech, innovation, and jurisdictional complexity—but stops short of deeper analysis. For each point, consider addressing: Who are the stakeholders? What evidence demonstrates the problem’s scale? Which regulatory models have succeeded or failed in practice?
# - The pro-regulation side would be stronger if you detail how proposed guidelines might work in practice (e.g., mandatory transparency reports, independent oversight bodies, algorithm audits).
# - On the minus side, you note risks of censorship and stifled innovation, but you could engage more directly with how regulations could be misused by authoritarian regimes or by incumbents to erect barriers.
# - Acknowledge and rebut counterarguments within each section. For instance, some social media companies have developed content‐moderation policies voluntarily—how effective are these, and why might government action still be needed?
#
# Writing Style
# - The academic tone is appropriate, but the list‐style format makes the essay feel impersonal. Introduce more varied sentence structures and occasional rhetorical questions (“How can we trust platforms to police themselves?”) to engage readers.
# - Aim for active voice where possible (“Regulators could mandate transparency” rather than “Regulatory measures could be mandated”). This change will lend urgency and clarity to your prose.
# - Finally, incorporate signposting phrases (“Firstly,” “On the other hand,” “Consequently,” “Nevertheless”) to guide the reader through your argument and highlight the logical flow between points.
#
# ✍️ Revised:
#
# **Title: Balancing Freedom and Responsibility: The Vital Role of Government Regulation on Social Media Platforms**
#
# **Introduction**
#
# In today's digitally connected society, where social media platforms wield unprecedented influence over public discourse, the debate around government regulation has gained momentum. Platforms like Facebook, Twitter, and Instagram shape opinions, affect political outcomes, and manage vast amounts of personal data. While some view regulation as a necessary step to mitigate misinformation and protect user privacy, others fear it could infringe on free speech and stifle innovation. This essay argues that government regulation of social media platforms is essential to ensure accountability, transparency, and fairness, provided it is implemented with careful consideration of fundamental freedoms and global complexities.
#
# **The Case for Regulation**
#
# Firstly, misinformation and harmful content proliferate on social media, with algorithms often amplifying sensational content that can lead to societal panic, violence, and erosion of trust in public institutions. Consider the spread of misinformation during the COVID-19 pandemic, where false narratives about cures and vaccines caused significant harm. Regulatory measures mandating transparency reports, independent oversight, and algorithm audits could hold platforms accountable and ensure responsible content moderation.
#
# Moreover, user privacy is under constant threat from the massive data collection practices of social media companies. The Cambridge Analytica scandal highlighted how personal data can be weaponized without users' informed consent. Implementing strong regulatory frameworks, like the European General Data Protection Regulation (GDPR), can empower users with more control over their data while imposing stringent accountability on companies for data breaches.
#
# Ensuring fairness and competition in the social media landscape is also crucial. Large tech companies often engage in monopolistic behavior that stifles startups and innovation. A well-designed regulatory framework could prevent anti-competitive practices, fostering a competitive environment that encourages diversity and innovation across the industry.
#
# Lastly, safeguarding democracy is paramount, as platforms have been implicated in election interference, notably in the 2016 U.S. elections. By mandating transparency in political advertising and imposing stricter controls on misinformation campaigns, governments can protect the integrity of democratic processes.
#
# **The Case Against Regulation**
#
# Conversely, there are significant concerns regarding the potential for censorship and infringement on free speech. While regulation aims to curb harmful content, there's a risk that authorities could misuse such powers to suppress dissenting voices or control narratives. For instance, in authoritarian regimes, regulations have been manipulated to silence opposition. To address this, regulatory models must balance content moderation with the protection of free expression, perhaps through mechanisms like independent oversight bodies.
#
# Furthermore, social media platforms drive technological innovation and economic growth. Imposing heavy regulations might stifle innovation and deter investment. Recognizing this, a nuanced regulatory approach is essential, one that promotes innovation without compromising public safety and privacy.
#
# Social media platforms operate globally, complicating regulatory efforts due to differing cultural norms and legal systems. Rapid technological advancements further challenge the establishment of universal regulations. Collaborative international frameworks might be necessary to navigate these complexities effectively.
#
# **Conclusion**
#
# Striking the right balance in regulating social media platforms is imperative for fostering a safe, fair, and innovative digital space. While the challenges of misinformation, privacy breaches, and monopolistic practices demand robust regulation, it is crucial to design frameworks that are transparent, adaptable, and respectful of free speech. Moving forward, governments should collaborate with industry leaders and civil society to develop guidelines that champion accountability and innovation. As we navigate the complexities of digital regulation, our collective efforts must ensure that social media remains a force for positive societal change, protecting democratic values and individual freedoms.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Necessity of Government Regulation on Social Media Platforms
#
# Introduction
#
# In an increasingly interconnected world, social media platforms wield immense power in shaping public discourse, influencing opinions, and even impacting the outcomes of elections. As these platforms have grown, so has the debate around whether they should be regulated by the government. Proponents argue that regulation is necessary to curb misinformation, protect user privacy, and ensure fair practices, while opponents claim it might infringe on free speech and stifle innovation. This essay explores the necessity of government regulation on social media platforms, weighing the potential benefits against the possible drawbacks.
#
# The Case for Regulation
#
# 1. **Curbing Misinformation and Harmful Content**: Social media has become a fertile ground for the spread of misinformation, fake news, and harmful content. These platforms employ algorithms that often prioritize sensational content, which can lead to real-world consequences such as panic, violence, or erosion of trust in public institutions. Government regulation could establish clear guidelines and accountability measures for the dissemination of content, ensuring that platforms take responsibility for monitoring and managing harmful content.
#
# 2. **Protecting User Privacy**: The vast amount of personal data collected by social media companies poses significant privacy concerns. Users often lack control over their data and may not fully understand the extent to which it is used or monetized. Regulatory frameworks, such as the European General Data Protection Regulation (GDPR), can enforce standards for data protection, giving users more control over their personal information and holding companies accountable for breaches.
#
# 3. **Ensuring Fairness and Competition**: Social media giants hold significant market power, often engaging in anti-competitive practices that stifle start-ups and innovation. Government intervention could ensure a level playing field by preventing monopolistic behavior and fostering a competitive environment that encourages diversity and innovation.
#
# 4. **Safeguarding Democracy**: Social media platforms have played a controversial role in democratic processes worldwide, with concerns about election interference through targeted ads and misinformation campaigns. Regulatory measures could mandate transparency in political advertising and enforce stricter controls on these practices to protect the integrity of elections.
#
# The Case Against Regulation
#
# 1. **Risk of Censorship and Free Speech Concerns**: One of the primary arguments against government regulation is the potential for censorship. Regulatory bodies might misuse their power to suppress dissent or control narratives, thereby infringing on free speech. This concern underscores the need for a balanced approach that protects freedom of expression while addressing harmful content.
#
# 2. **Innovation and Economic Growth**: Social media platforms have been at the forefront of technological innovation, creating jobs and contributing significantly to economic growth. Overregulation might stifle innovation and deter investment in the industry. It is crucial to find a regulatory approach that does not hinder the technological advancement and entrepreneurial spirit that drive these platforms.
#
# 3. **Global and Legislative Complexity**: Social media platforms operate on a global scale, complicating regulatory efforts. Different countries have varying cultural norms and legal systems, making it challenging to implement universal regulations. Additionally, rapidly evolving technology means that regulations can quickly become outdated or insufficient.
#
# Conclusion
#
# The regulation of social media platforms by the government presents a complex challenge, requiring a careful balance between safeguarding public interests and preserving fundamental freedoms. While the risks associated with misinformation, privacy breaches, and unfair practices are too significant to ignore, it is crucial that any regulatory framework is transparent, adaptable, and respectful of free speech. A collaborative approach involving governments, industry leaders, and civil society can help build a regulatory environment that promotes responsibility, innovation, and the protection of democratic values. As social media continues to evolve, so too must the strategies to ensure its positive role in society.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Structure
# - The overall organization into “Case for” and “Case against” sections is clear and logical, but the essay reads more like an outline than a flowing argument. Consider weaving these points into full paragraphs with smoother transitions so the reader follows the narrative, rather than jumping between numbered lists.
# - Your introduction sets up the debate well, but it could be strengthened by a more precise thesis statement that previews which side you find more compelling (or under what conditions regulation is justified).
# - The conclusion restates the need for balance, but it would benefit from a stronger call to action or a summary of your key recommendations (for example, specific regulatory principles or next steps).
#
# Clarity
# - The language is generally clear, but several sections rely heavily on broad generalizations (e.g., “real-world consequences,” “significant privacy concerns”). Citing concrete examples—such as the Cambridge Analytica scandal, 2016 election interference, or a landmark GDPR enforcement action—will ground your claims.
# - Watch for repetition of terms like “platforms,” “regulation,” and “harmful content.” Vary your wording or combine similar ideas to avoid redundancy and tighten your prose.
# - Some sentences are lengthy and pack multiple ideas. Breaking these into shorter, focused sentences will improve readability.
#
# Strength of Argument
# - Your essay identifies the central issues—misinformation, privacy, competition, democracy, free speech, innovation, and jurisdictional complexity—but stops short of deeper analysis. For each point, consider addressing: Who are the stakeholders? What evidence demonstrates the problem’s scale? Which regulatory models have succeeded or failed in practice?
# - The pro-regulation side would be stronger if you detail how proposed guidelines might work in practice (e.g., mandatory transparency reports, independent oversight bodies, algorithm audits).
# - On the minus side, you note risks of censorship and stifled innovation, but you could engage more directly with how regulations could be misused by authoritarian regimes or by incumbents to erect barriers.
# - Acknowledge and rebut counterarguments within each section. For instance, some social media companies have developed content‐moderation policies voluntarily—how effective are these, and why might government action still be needed?
#
# Writing Style
# - The academic tone is appropriate, but the list‐style format makes the essay feel impersonal. Introduce more varied sentence structures and occasional rhetorical questions (“How can we trust platforms to police themselves?”) to engage readers.
# - Aim for active voice where possible (“Regulators could mandate transparency” rather than “Regulatory measures could be mandated”). This change will lend urgency and clarity to your prose.
# - Finally, incorporate signposting phrases (“Firstly,” “On the other hand,” “Consequently,” “Nevertheless”) to guide the reader through your argument and highlight the logical flow between points.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">**Title: Balancing Freedom and Responsibility: The Vital Role of Government Regulation on Social Media Platforms**
#
# **Introduction**
#
# In today's digitally connected society, where social media platforms wield unprecedented influence over public discourse, the debate around government regulation has gained momentum. Platforms like Facebook, Twitter, and Instagram shape opinions, affect political outcomes, and manage vast amounts of personal data. While some view regulation as a necessary step to mitigate misinformation and protect user privacy, others fear it could infringe on free speech and stifle innovation. This essay argues that government regulation of social media platforms is essential to ensure accountability, transparency, and fairness, provided it is implemented with careful consideration of fundamental freedoms and global complexities.
#
# **The Case for Regulation**
#
# Firstly, misinformation and harmful content proliferate on social media, with algorithms often amplifying sensational content that can lead to societal panic, violence, and erosion of trust in public institutions. Consider the spread of misinformation during the COVID-19 pandemic, where false narratives about cures and vaccines caused significant harm. Regulatory measures mandating transparency reports, independent oversight, and algorithm audits could hold platforms accountable and ensure responsible content moderation.
#
# Moreover, user privacy is under constant threat from the massive data collection practices of social media companies. The Cambridge Analytica scandal highlighted how personal data can be weaponized without users' informed consent. Implementing strong regulatory frameworks, like the European General Data Protection Regulation (GDPR), can empower users with more control over their data while imposing stringent accountability on companies for data breaches.
#
# Ensuring fairness and competition in the social media landscape is also crucial. Large tech companies often engage in monopolistic behavior that stifles startups and innovation. A well-designed regulatory framework could prevent anti-competitive practices, fostering a competitive environment that encourages diversity and innovation across the industry.
#
# Lastly, safeguarding democracy is paramount, as platforms have been implicated in election interference, notably in the 2016 U.S. elections. By mandating transparency in political advertising and imposing stricter controls on misinformation campaigns, governments can protect the integrity of democratic processes.
#
# **The Case Against Regulation**
#
# Conversely, there are significant concerns regarding the potential for censorship and infringement on free speech. While regulation aims to curb harmful content, there's a risk that authorities could misuse such powers to suppress dissenting voices or control narratives. For instance, in authoritarian regimes, regulations have been manipulated to silence opposition. To address this, regulatory models must balance content moderation with the protection of free expression, perhaps through mechanisms like independent oversight bodies.
#
# Furthermore, social media platforms drive technological innovation and economic growth. Imposing heavy regulations might stifle innovation and deter investment. Recognizing this, a nuanced regulatory approach is essential, one that promotes innovation without compromising public safety and privacy.
#
# Social media platforms operate globally, complicating regulatory efforts due to differing cultural norms and legal systems. Rapid technological advancements further challenge the establishment of universal regulations. Collaborative international frameworks might be necessary to navigate these complexities effectively.
#
# **Conclusion**
#
# Striking the right balance in regulating social media platforms is imperative for fostering a safe, fair, and innovative digital space. While the challenges of misinformation, privacy breaches, and monopolistic practices demand robust regulation, it is crucial to design frameworks that are transparent, adaptable, and respectful of free speech. Moving forward, governments should collaborate with industry leaders and civil society to develop guidelines that champion accountability and innovation. As we navigate the complexities of digital regulation, our collective efforts must ensure that social media remains a force for positive societal change, protecting democratic values and individual freedoms.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
