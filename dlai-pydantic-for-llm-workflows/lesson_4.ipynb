# %% [markdown]
# # Lesson 4: Using Pydantic Models for Structured LLM Output
#
# In the previous lesson, you implemented retry mechanisms to handle validation errors, which mimics what some structured output frameworks are doing behind the scenes when they handle validation for you.
#
# In this lesson, you'll experiment with passing you Pydantic model directly in your API call using different frameworks and LLM providers.
#
# By the end of this lesson, you'll be able to:
# - Use Pydantic models directly in your API calls to LLMs
# - Reliably receive a properly structured response using a variety of different frameworks and LLM providers.
#
# ---
#
# ### Import all required libraries and set up your environment

# %%
# Import packages
from pydantic import BaseModel, Field, EmailStr
from typing import List, Literal, Optional
from openai import OpenAI
import instructor
import anthropic
from dotenv import load_dotenv
from datetime import date
import os

# %%
# Load environment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Define your Pydantic models for user input and LLM output

# %%
# Define the UserInput model for customer support queries
class UserInput(BaseModel):
    name: str
    email: EmailStr
    query: str
    order_id: Optional[int] = Field(
        None,
        description="5-digit order number (cannot start with 0)",
        ge=10000,
        le=99999
    )
    purchase_date: Optional[date] = None

# Define the CustomerQuery model that inherits from UserInput
class CustomerQuery(UserInput):
    priority: str = Field(
        ..., description="Priority level: low, medium, high"
    )
    category: Literal[
        'refund_request', 'information_request', 'other'
    ] = Field(..., description="Query category")
    is_complaint: bool = Field(
        ..., description="Whether this is a complaint"
    )
    tags: List[str] = Field(..., description="Relevant keyword tags")

# %%
CustomerQuery.
# Out:
# __main__.CustomerQuery

# %% [markdown]
# ### Provide sample input and validate it using your model

# %%
# Define your input data as a JSON string
user_input_json = '''{
    "name": "Joe User",
    "email": "joe.user@example.com",
    "query": "I ordered a new computer monitor and it arrived with the screen cracked. This is the second time this has happened. I need a replacement ASAP.",
    "order_number": 12345,
    "purchase_date": "2025-12-31"
}'''

# %%
# Validate the user_input_json by creating a UserInput instance
user_input = UserInput.model_validate_json(user_input_json)
print(user_input)
# Out:
# name='Joe User' email='joe.user@example.com' query='I ordered a new computer monitor and it arrived with the screen cracked. This is the second time this has happened. I need a replacement ASAP.' order_id=None purchase_date=datetime.date(2025, 12, 31)

# %% [markdown]
# ### Build a prompt and call the Anthropic API with the instructor package for structured output

# %%
prompt = (
    f"Analyze the following customer query {user_input} "
    f"and provide a structured response."
)

# %%
# Use Anthropic with Instructor to get structured output
anthropic_client = instructor.from_anthropic(
    anthropic.Anthropic()
)

response = anthropic_client.messages.create(
    model="claude-3-7-sonnet-latest",  
    max_tokens=1024,
    messages=[
        {
            "role": "user", 
            "content": prompt
        }
    ],
    response_model=CustomerQuery  
)

# %%
# Inspect the returned structured data
print(type(response))
print(response.model_dump_json(indent=2))

# %% [markdown]
# ### Use OpenAI's structured output API with your Pydantic schema

# %%
# Initialize OpenAI client and call passing CustomerQuery in your API call
# openai_client = OpenAI()
openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"), base_url=os.getenv("OPENAI_API_BASE"))
response = openai_client.beta.chat.completions.parse(
    model="gpt-4o",
    messages=[{"role": "user", "content": prompt}],
    response_format=CustomerQuery
)
response_content = response.choices[0].message.content
print(type(response_content))
print(response_content)
# Out:
# <class 'str'>
# {"name":"Joe User","email":"joe.user@example.com","query":"I ordered a new computer monitor and it arrived with the screen cracked. This is the second time this has happened. I need a replacement ASAP.","order_id":null,"purchase_date":null,"priority":"high","category":"other","is_complaint":true,"tags":["cracked screen","replacement","monitor","repeat issue"]}

# %% [markdown]
# ### Additional advanced usage and inspection

# %%
# Validate the repsonse you got from the LLM
valid_data = CustomerQuery.model_validate_json(
    response_content
)
print(type(valid_data))
print(valid_data.model_dump_json(indent=2))
# Out:
# <class '__main__.CustomerQuery'>
# {
#   "name": "Joe User",
#   "email": "joe.user@example.com",
#   "query": "I ordered a new computer monitor and it arrived with the screen cracked. This is the second time this has happened. I need a replacement ASAP.",
#   "order_id": null,
#   "purchase_date": null,
#   "priority": "high",
#   "category": "other",
#   "is_complaint": true,
#   "tags": [
#     "cracked screen",
#     "replacement",
#     "monitor",
#     "repeat issue"
#   ]
# }

# %%
# Try the responses API from OpenAI
response = openai_client.responses.parse(
    model="gpt-4o",
    input=[{"role": "user", "content": prompt}],
    text_format=CustomerQuery
)

print(type(response))
# Out:
# <class 'openai.types.responses.parsed_response.ParsedResponse[CustomerQuery]'>

# %%
# Investigate class inheritance structure of the OpenAI response
def print_class_inheritence(llm_response):
    for cls in type(llm_response).mro():
        print(f"{cls.__module__}.{cls.__name__}")

print_class_inheritence(response)
# Out:
# openai.types.responses.parsed_response.ParsedResponse[CustomerQuery]
# openai.types.responses.parsed_response.ParsedResponse
# openai.types.responses.response.Response
# openai._models.GenericModel
# openai._compat.GenericModel
# openai.BaseModel
# pydantic.main.BaseModel
# typing.Generic
# builtins.object

# %%
# Print the response type and content 
print(type(response.output_parsed))
print(response.output_parsed.model_dump_json(indent=2))
# Out:
# <class '__main__.CustomerQuery'>
# {
#   "name": "Joe User",
#   "email": "joe.user@example.com",
#   "query": "I ordered a new computer monitor and it arrived with the screen cracked. This is the second time this has happened. I need a replacement ASAP.",
#   "order_id": null,
#   "purchase_date": "2025-12-31",
#   "priority": "high",
#   "category": "refund_request",
#   "is_complaint": true,
#   "tags": [
#     "damaged_goods",
#     "replacement_request",
#     "urgent"
#   ]
# }

# %%
# Try out the Pydantic AI package for defining an agent and getting a structured response
from pydantic_ai import Agent
import nest_asyncio
nest_asyncio.apply()

agent = Agent(
    model="openai:gpt-4o",
    output_type=CustomerQuery,
    model_settings={"api_key": os.getenv("OPENAI_API_KEY"),"openai_api_base": os.getenv("OPENAI_API_BASE")}
)
response = agent.run_sync(prompt)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/pydantic_ai/models/openai.py:404, in OpenAIModel._completions_create(self, messages, stream, model_settings, model_request_parameters)
#     403     extra_headers.setdefault('User-Agent', get_user_agent())
# --> 404     return await self.client.chat.completions.create(
#     405         model=self._model_name,
#     406         messages=openai_messages,
#     407         parallel_tool_calls=model_settings.get('parallel_tool_calls', NOT_GIVEN),
#     408         tools=tools or NOT_GIVEN,
#     409         tool_choice=tool_choice or NOT_GIVEN,
#     410         stream=stream,
#     411         stream_options={'include_usage': True} if stream else NOT_GIVEN,
#     412         stop=model_settings.get('stop_sequences', NOT_GIVEN),
#     413         max_completion_tokens=model_settings.get('max_tokens', NOT_GIVEN),
#     414         timeout=model_settings.get('timeout', NOT_GIVEN),
#     415         response_format=response_format or NOT_GIVEN,
#     416         seed=model_settings.get('seed', NOT_GIVEN),
#     417         reasoning_effort=model_settings.get('openai_reasoning_effort', NOT_GIVEN),
#     418         user=model_settings.get('openai_user', NOT_GIVEN),
#     419         web_search_options=web_search_options or NOT_GIVEN,
#     420         service_tier=model_settings.get('openai_service_tier', NOT_GIVEN),
#     421         prediction=model_settings.get('openai_prediction', NOT_GIVEN),
#     422         temperature=sampling_settings.get('temperature', NOT_GIVEN),
#     423         top_p=sampling_settings.get('top_p', NOT_GIVEN),
#     424         presence_penalty=sampling_settings.get('presence_penalty', NOT_GIVEN),
#     425         frequency_penalty=sampling_settings.get('frequency_penalty', NOT_GIVEN),
#     426         logit_bias=sampling_settings.get('logit_bias', NOT_GIVEN),
#     427         logprobs=sampling_settings.get('openai_logprobs', NOT_GIVEN),
#     428         top_logprobs=sampling_settings.get('openai_top_logprobs', NOT_GIVEN),
#     429         extra_headers=extra_headers,
#     430         extra_body=model_settings.get('extra_body'),
#     431     )
#     432 except APIStatusError as e:
#
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:2583, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2582 validate_response_format(response_format)
# -> 2583 return await self._post(
#    2584     "/chat/completions",
#    2585     body=await async_maybe_transform(
#    2586         {
#    2587             "messages": messages,
#    2588             "model": model,
#    2589             "audio": audio,
#    2590             "frequency_penalty": frequency_penalty,
#    2591             "function_call": function_call,
#    2592             "functions": functions,
#    2593             "logit_bias": logit_bias,
#    2594             "logprobs": logprobs,
#    2595             "max_completion_tokens": max_completion_tokens,
#    2596             "max_tokens": max_tokens,
#    2597             "metadata": metadata,
#    2598             "modalities": modalities,
#    2599             "n": n,
#    2600             "parallel_tool_calls": parallel_tool_calls,
#    2601             "prediction": prediction,
#    2602             "presence_penalty": presence_penalty,
#    2603             "prompt_cache_key": prompt_cache_key,
#    2604             "reasoning_effort": reasoning_effort,
#    2605             "response_format": response_format,
#    2606             "safety_identifier": safety_identifier,
#    2607             "seed": seed,
#    2608             "service_tier": service_tier,
#    2609             "stop": stop,
#    2610             "store": store,
#    2611             "stream": stream,
#    2612             "stream_options": stream_options,
#    2613             "temperature": temperature,
#    2614             "tool_choice": tool_choice,
#    2615             "tools": tools,
#    2616             "top_logprobs": top_logprobs,
#    2617             "top_p": top_p,
#    2618             "user": user,
#    2619             "verbosity": verbosity,
#    2620             "web_search_options": web_search_options,
#    2621         },
#    2622         completion_create_params.CompletionCreateParamsStreaming
#    2623         if stream
#    2624         else completion_create_params.CompletionCreateParamsNonStreaming,
#    2625     ),
#    2626     options=make_request_options(
#    2627         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2628     ),
#    2629     cast_to=ChatCompletion,
#    2630     stream=stream or False,
#    2631     stream_cls=AsyncStream[ChatCompletionChunk],
#    2632 )
#
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/openai/_base_client.py:1794, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1791 opts = FinalRequestOptions.construct(
#    1792     method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1793 )
# -> 1794 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/openai/_base_client.py:1594, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1593     log.debug("Re-raising status error")
# -> 1594     raise self._make_status_error_from_response(err.response) from None
#    1596 break
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: gl-U2Fsd*******************************************************3vpr. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
#
# The above exception was the direct cause of the following exception:
#
# ModelHTTPError                            Traceback (most recent call last)
# Cell In[31], line 11
#       4 nest_asyncio.apply()
#       6 agent = Agent(
#       7     model="openai:gpt-4o",
#       8     output_type=CustomerQuery,
#       9     model_settings={"api_key": os.getenv("OPENAI_API_KEY"),"openai_api_base": os.getenv("OPENAI_API_BASE")}
#      10 )
# ---> 11 response = agent.run_sync(prompt)
#
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/pydantic_ai/agent/abstract.py:317, in AbstractAgent.run_sync(self, user_prompt, output_type, message_history, model, deps, model_settings, usage_limits, usage, infer_name, toolsets, event_stream_handler)
#     314 if infer_name and self.name is None:
#     315     self._infer_name(inspect.currentframe())
# --> 317 return get_event_loop().run_until_complete(
#     318     self.run(
#     319         user_prompt,
#     320         output_type=output_type,
#     321         message_history=message_history,
#     322         model=model,
#     323         deps=deps,
#     324         model_settings=model_settings,
#     325         usage_limits=usage_limits,
#     326         usage=usage,
#     327         infer_name=False,
#     328         toolsets=toolsets,
#     329         event_stream_handler=event_stream_handler,
#     330     )
#     331 )
#
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/pydantic_ai/agent/abstract.py:222, in AbstractAgent.run(self, user_prompt, output_type, message_history, model, deps, model_settings, usage_limits, usage, infer_name, toolsets, event_stream_handler)
#     209 event_stream_handler = event_stream_handler or self.event_stream_handler
#     211 async with self.iter(
#     212     user_prompt=user_prompt,
#     213     output_type=output_type,
#    (...)    220     toolsets=toolsets,
#     221 ) as agent_run:
# --> 222     async for node in agent_run:
#     223         if event_stream_handler is not None and (
#     224             self.is_model_request_node(node) or self.is_call_tools_node(node)
#     225         ):
#     226             async with node.stream(agent_run.ctx) as stream:
#
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/pydantic_ai/run.py:149, in AgentRun.__anext__(self)
#     145 async def __anext__(
#     146     self,
#     147 ) -> _agent_graph.AgentNode[AgentDepsT, OutputDataT] | End[FinalResult[OutputDataT]]:
#     148     """Advance to the next node automatically based on the last returned node."""
# --> 149     next_node = await self._graph_run.__anext__()
#     150     if _agent_graph.is_agent_node(node=next_node):
#     151         return next_node
#
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/pydantic_graph/graph.py:771, in GraphRun.__anext__(self)
#     768 if isinstance(self._next_node, End):
#     769     raise StopAsyncIteration
# --> 771 return await self.next(self._next_node)
#
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/pydantic_graph/graph.py:744, in GraphRun.next(self, node)
#     742     async with self.persistence.record_run(node_snapshot_id):
#     743         ctx = GraphRunContext(self.state, self.deps)
# --> 744         self._next_node = await node.run(ctx)
#     746 if isinstance(self._next_node, End):
#     747     self._snapshot_id = self._next_node.get_snapshot_id()
#
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/pydantic_ai/_agent_graph.py:297, in ModelRequestNode.run(self, ctx)
#     292 if self._did_stream:
#     293     # `self._result` gets set when exiting the `stream` contextmanager, so hitting this
#     294     # means that the stream was started but not finished before `run()` was called
#     295     raise exceptions.AgentRunError('You must finish streaming before calling run()')  # pragma: no cover
# --> 297 return await self._make_request(ctx)
#
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/pydantic_ai/_agent_graph.py:339, in ModelRequestNode._make_request(self, ctx)
#     336     return self._result  # pragma: no cover
#     338 model_settings, model_request_parameters, message_history, _ = await self._prepare_request(ctx)
# --> 339 model_response = await ctx.deps.model.request(message_history, model_settings, model_request_parameters)
#     340 ctx.state.usage.requests += 1
#     342 return self._finish_handling(ctx, model_response)
#
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/pydantic_ai/models/openai.py:324, in OpenAIModel.request(self, messages, model_settings, model_request_parameters)
#     317 async def request(
#     318     self,
#     319     messages: list[ModelMessage],
#     320     model_settings: ModelSettings | None,
#     321     model_request_parameters: ModelRequestParameters,
#     322 ) -> ModelResponse:
#     323     check_allow_model_requests()
# --> 324     response = await self._completions_create(
#     325         messages, False, cast(OpenAIModelSettings, model_settings or {}), model_request_parameters
#     326     )
#     327     model_response = self._process_response(response)
#     328     return model_response
#
# File ~/Library/CloudStorage/OneDrive-GeorgiaInstituteofTechnology/mr-rahul-aggarwal-git-hub/online-courses/dlai-pydantic-for-llm-workflows/.venv/lib/python3.13/site-packages/pydantic_ai/models/openai.py:434, in OpenAIModel._completions_create(self, messages, stream, model_settings, model_request_parameters)
#     432 except APIStatusError as e:
#     433     if (status_code := e.status_code) >= 400:
# --> 434         raise ModelHTTPError(status_code=status_code, model_name=self.model_name, body=e.body) from e
#     435     raise
#
# ModelHTTPError: status_code: 401, model_name: gpt-4o, body: {'message': 'Incorrect API key provided: gl-U2Fsd*******************************************************3vpr. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}

# %%
# Print out the repsonse type and content
print(type(response.output))
print(response.output.model_dump_json(indent=2))

# %% [markdown]
# ---
#
# ## Conclusion
#
# In this lesson, you learned how to use Pydantic models to extract structured, validated output directly from LLMs using both OpenAI and Anthropic APIs. By defining your expected output schema with Pydantic and passing it directly to the API, you can eliminate manual parsing and validation code and receive reliable, well-formed responses in a single API call. This approach lets you focus on designing clear data models and prompts, making your code more maintainable and robust.
