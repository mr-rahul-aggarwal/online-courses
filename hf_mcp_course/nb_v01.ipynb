# %%
x=1
x
# Out:
# 1

# %%
# alias mcp-env='export NVM_DIR="$HOME/.nvm" && [ -s "$NVM_DIR/nvm.sh" ] && \. "$NVM_DIR/nvm.sh" && export PATH="$HOME/.local/bin:$PATH"'
# mcp-env && mcp dev server.py

# %%
# export NVM_DIR="$HOME/.nvm" && [ -s "$NVM_DIR/nvm.sh" ] && \. "$NVM_DIR/nvm.sh" && export PATH="$HOME/.local/bin:$PATH" && uv run mcp dev server.py
